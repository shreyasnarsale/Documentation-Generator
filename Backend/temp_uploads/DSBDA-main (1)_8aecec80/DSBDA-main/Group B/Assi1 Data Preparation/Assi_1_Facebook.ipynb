# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Load the Dataset

# %%
data = pd.read_csv("dataset_Facebook.csv", delimiter=";", encoding="utf-8")
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# # Checking Null values

# %%
data.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df = data.dropna()

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
data.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %% [markdown]
# # A) Create data subsets

# %% [markdown]
# # Subset 1: Posts with more than 100 likes

# %%
subset1 = df[df["like"] > 100]
subset1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# ..                ...     ...       ...         ...           ...        ...
# 488             85979   Photo         3           1             7         10
# 491             85979   Photo         3           1             6          3
# 492             85979    Link         1           1             5         11
# 493             85093   Photo         3           1             1          2
# 494             85093   Photo         3           1             7         10
#
# ...

# %% [markdown]
# # Subset 2: Posts of type 'Photo'

# %%
subset2 = df[df["Type"] == "Photo"]
subset2
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 494             85093  Photo         3           1             7         10
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
#
# ...

# %% [markdown]
# # Subset 3: Posts published on weekdays only

# %%
subset3 = df[df['Post Weekday'] < 6]
subset3
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 492             85979    Link         1           1             5         11
# 493             85093   Photo         3           1             1          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
#
# ...

# %% [markdown]
# # Subset 4: Subset for the columns like, share, and comment

# %%
subset4 = df[['Lifetime Post Total Impressions', 'like', 'share', 'comment']]
subset4
# Out:
#      Lifetime Post Total Impressions    like  share  comment
# 0                               5091    79.0   17.0        4
# 1                              19057   130.0   29.0        5
# 2                               4373    66.0   14.0        0
# 3                              87991  1572.0  147.0       58
# 4                              13594   325.0   49.0       19
# ..                               ...     ...    ...      ...
# 494                             9218   125.0   41.0       10
# 495                             7536    53.0   26.0        5
# 496                             6229    53.0   22.0        0
# 497                             7216    93.0   18.0        4
# 498                             7564    91.0   38.0        7
#
# [495 rows x 4 columns]

# %% [markdown]
# # Subset 5: Subset for the columns like, Category, and Type

# %%
subset5 = df[['Lifetime Post Total Impressions', 'like','Category', 'Type']]
subset5
# Out:
#      Lifetime Post Total Impressions    like  Category    Type
# 0                               5091    79.0         2   Photo
# 1                              19057   130.0         2  Status
# 2                               4373    66.0         3   Photo
# 3                              87991  1572.0         2   Photo
# 4                              13594   325.0         2   Photo
# ..                               ...     ...       ...     ...
# 494                             9218   125.0         3   Photo
# 495                             7536    53.0         3   Photo
# 496                             6229    53.0         2   Photo
# 497                             7216    93.0         1   Photo
# 498                             7564    91.0         3   Photo
#
# [495 rows x 4 columns]

# %% [markdown]
# # Subsets Using Slicing (2 subsets)

# %% [markdown]
# # Subset 6: First 100 rows

# %%
subset6 = df.iloc[:100]
subset6
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             139441   Photo         2          12             4          3
# 1             139441  Status         2          12             3         10
# 2             139441   Photo         3          12             3          3
# 3             139441   Photo         2          12             2         10
# 4             139441   Photo         2          12             2          3
# ..               ...     ...       ...         ...           ...        ...
# 95            137059   Photo         3          10             6         10
# 96            137059   Photo         1          10             6          3
# 97            137059   Photo         2          10             5         11
# 98            137020  Status         2          10             5          3
# 99            137020   Photo         1          10             4         10
#
# ...

# %% [markdown]
# # Subset 7: Select only 'Type' and 'like' columns for all rows

# %%
subset7 = df.loc[:, ['Type', 'like']]
subset7
# Out:
#        Type    like
# 0     Photo    79.0
# 1    Status   130.0
# 2     Photo    66.0
# 3     Photo  1572.0
# 4     Photo   325.0
# ..      ...     ...
# 494   Photo   125.0
# 495   Photo    53.0
# 496   Photo    53.0
# 497   Photo    93.0
# 498   Photo    91.0
#
# [495 rows x 2 columns]

# %% [markdown]
# # B) Merge Data

# %% [markdown]
# # Concatenating row-wise (axis=0)

# %%
merged_row_wise = pd.concat([subset1, subset2], axis=0)  # Merging two subsets vertically
merged_row_wise
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# ..                ...     ...       ...         ...           ...        ...
# 494             85093   Photo         3           1             7         10
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
#
# ...

# %% [markdown]
# # Merge Column-wise

# %%
merged_df = pd.merge(subset4, subset5, on = ['Lifetime Post Total Impressions', 'like'], how='left')
merged_df
# Out:
#      Lifetime Post Total Impressions    like  share  comment  Category    Type
# 0                               5091    79.0   17.0        4         2   Photo
# 1                              19057   130.0   29.0        5         2  Status
# 2                               4373    66.0   14.0        0         3   Photo
# 3                              87991  1572.0  147.0       58         2   Photo
# 4                              13594   325.0   49.0       19         2   Photo
# ..                               ...     ...    ...      ...       ...     ...
# 490                             9218   125.0   41.0       10         3   Photo
# 491                             7536    53.0   26.0        5         3   Photo
# 492                             6229    53.0   22.0        0         2   Photo
# 493                             7216    93.0   18.0        4         1   Photo
# 494                             7564    91.0   38.0        7         3   Photo
#
# [495 rows x 6 columns]

# %%
# merged_column_wise = pd.concat([subset4,subset5], axis=1)
# merged_column_wise

# %%
# # Check how many duplicates exist in 'like' column
# print(subset4['Lifetime Post Total Impressions'].value_counts())
# print(subset5['Lifetime Post Total Impressions'].value_counts())

# %%
# # Remove duplicates based on merging column
# subset4_unique = subset4.drop_duplicates(subset=['Lifetime Post Total Impressions'])
# subset5_unique = subset5.drop_duplicates(subset=['Lifetime Post Total Impressions'])

# %%
# # Merge to retain all rows from subset0
# merged_df = pd.merge(subset4_unique, subset5_unique,  how='left')
# # merged_d

# %%
for col in df.columns:
    print(f"Unique values in '{col}':", df[col].nunique())
# Out:
# Unique values in 'Page total likes': 90
# Unique values in 'Type': 4
# Unique values in 'Category': 3
# Unique values in 'Post Month': 12
# Unique values in 'Post Weekday': 7
# Unique values in 'Post Hour': 22
# Unique values in 'Paid': 2
# Unique values in 'Lifetime Post Total Reach': 481
# Unique values in 'Lifetime Post Total Impressions': 489
# Unique values in 'Lifetime Engaged Users': 411
# Unique values in 'Lifetime Post Consumers': 418
# Unique values in 'Lifetime Post Consumptions': 436
# Unique values in 'Lifetime Post Impressions by people who have liked your Page': 487
# Unique values in 'Lifetime Post reach by people who like your Page': 464
# Unique values in 'Lifetime People who have liked your Page and engaged with your post': 378
# Unique values in 'comment': 46
# Unique values in 'like': 257
# Unique values in 'share': 88
# Unique values in 'Total Interactions': 280

# %% [markdown]
# # C) Sorting ascending and descending order for single column and multiple columns

# %% [markdown]
# # Sort by Likes in Ascending Order

# %%
sorted_data = df.sort_values(by='like', ascending=True)
sorted_data
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 417            104070  Photo         1           3             3         10
# 441             98195  Photo         1           3             5          4
# 100            137020  Photo         1          10             4          9
# 76             137893  Photo         1          11             3          2
# 21             138414  Photo         1          12             7         10
# ..                ...    ...       ...         ...           ...        ...
# 3              139441  Photo         2          12             2         10
# 168            135428  Photo         1           9             3         10
# 349            117764  Photo         3           5             5         13
# 379            111620  Photo         3           4             1         14
# 244            130791  Photo         2           7             3          5
#
# ...

# %% [markdown]
# # Sort by Likes in Descending Order

# %%
sorted_data = df.sort_values(by='like', ascending=False)
sorted_data
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 349            117764  Photo         3           5             5         13
# 168            135428  Photo         1           9             3         10
# 3              139441  Photo         2          12             2         10
# ..                ...    ...       ...         ...           ...        ...
# 76             137893  Photo         1          11             3          2
# 441             98195  Photo         1           3             5          4
# 417            104070  Photo         1           3             3         10
# 21             138414  Photo         1          12             7         10
# 100            137020  Photo         1          10             4          9
#
# ...

# %% [markdown]
# # Sorts by Multiple Columns

# %%
sorted_df = df.sort_values(by=['Type', 'like'], ascending=[True, False])
sorted_df
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 403            107907   Link         1           4             2          6
# 41             138895   Link         1          12             6          3
# 140            136013   Link         1          10             4          3
# 86             137177   Link         1          11             4          3
# 492             85979   Link         1           1             5         11
# ..                ...    ...       ...         ...           ...        ...
# 243            130791  Video         1           7             3         11
# 277            126424  Video         1           6             2         13
# 29             138895  Video         1          12             4         11
# 74             137893  Video         1          11             3         11
# 55             138329  Video         1          11             6          2
#
# ...

# %% [markdown]
# # D) Transposing Data

# %%
transposed_data = df.T
transposed_data
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %% [markdown]
# # E) Shape and Reshape Data

# %%
data.shape
# Out:
# (500, 19)

# %% [markdown]
# # Reshape Data

# %% [markdown]
# # i) Wide to Long Format

# %%
melted_data = df.melt(id_vars=['Type'], value_vars=['like', 'share', 'comment'])
melted_data.head()
# Out:
#      Type variable   value
# 0   Photo     like    79.0
# 1  Status     like   130.0
# 2   Photo     like    66.0
# 3   Photo     like  1572.0
# 4   Photo     like   325.0

# %% [markdown]
# # ii) Long to Wide Format

# %%
pivoted_data = melted_data.pivot_table(index='Type', columns='variable', values='value', aggfunc='sum')
pivoted_data.head()
# Out:
# variable  comment     like    share
# Type
# Link         62.0   1613.0    284.0
# Photo      3192.0  77492.0  11433.0
# Status      401.0   7952.0   1414.0
# Video        86.0   1620.0    365.0

# %% [markdown]
# # iii) Remove Duplicates Before Pivoting

# %%
melted_data = melted_data.drop_duplicates(subset=['Type', 'variable'])
melted_data
# Out:
#         Type variable  value
# 0      Photo     like   79.0
# 1     Status     like  130.0
# 22      Link     like   16.0
# 29     Video     like  143.0
# 495    Photo    share   17.0
# 496   Status    share   29.0
# 517     Link    share    2.0
# 524    Video    share   13.0
# 990    Photo  comment    4.0
# 991   Status  comment    5.0
# 1012    Link  comment    0.0
# 1019   Video  comment   18.0

# %% [markdown]
# # iv) Pivot the data

# %%
pivoted_data = melted_data.pivot(index='Type', columns='variable', values='value')
pivoted_data
# Out:
# variable  comment   like  share
# Type
# Link          0.0   16.0    2.0
# Photo         4.0   79.0   17.0
# Status        5.0  130.0   29.0
# Video        18.0  143.0   13.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Countplot

# %%
# plt.figure(figsize=(10,6))
# sns.countplot(x='Category', data=df, palette='viridis')
# plt.title("Category Distribution")
# plt.show()

# %%
# Scatterplot

# %%
# plt.figure(figsize=(10,6))
# sns.scatterplot(x="like", y="share", data=df, hue="Type", style="Type", s=100)
# plt.xlabel("Likes")
# plt.ylabel("Shares")
# plt.title("Likes vs Shares")
# plt.show()

# %%
# Boxplot

# %%
# plt.figure(figsize=(10,6))
# sns.boxplot(x="Type",y="like",data=df,palette='rainbow')
# plt.xlabel("Post Type")
# plt.ylabel("Likes")
# plt.title("Post Type vs Likes")
# plt.show()

# %%
# Barplot

# %%
# plt.figure(figsize=(10,6))
# sns.barplot(x="Type",y="like",data=df, color ="salmon")
# plt.xlabel("Post Type")
# plt.ylabel("Likes")
# plt.title("Post Type vs Likes")
# plt.show()

# %%
# Histogram

# %%
# plt.figure(figsize=(10,6))
# sns.histplot(df['Lifetime Post Total Reach'], bins=30, kde=True, color='red', alpha=0.6, linewidth=2, edgecolor='black', element='step',stat='density')
# plt.xlabel("Lifetime Post Total Reach")
# plt.ylabel("Frequency")
# plt.title("Likes Distributtion")
# plt.show()

# %%
# Pairplot

# %%
# sns.pairplot(df[['like', 'share', 'comment']])
# plt.show()

# %%
# Heatmap

# %%
# plt.figure(figsize=(10,6))
# numerical_df = df.select_dtypes(include=[np.number])
# sns.heatmap(numerical_df.corr(), annot=True, cmap='coolwarm', linewidth=2)
# plt.title("Correlation Heatmap")
# plt.show()

# %%
# Lineplot

# %%
# plt.figure(figsize=(10,6))
# sns.lineplot(x="like", y="share", data=df, hue="Type", style="Type", markers=True)
# plt.xlabel("Likes")
# plt.ylabel("Shares")
# plt.title("Likes vs Shares")
# plt.show()

# %%
# Piechart

# %%
# plt.figure(figsize=(10,6))
# df['Category'].value_counts().plot(kind='pie', autopct='%1.1f%%', shadow=True, startangle=90, legend=True, labels=None, pctdistance=0.8)
# plt.title("Category Distribution")
# plt.show()
