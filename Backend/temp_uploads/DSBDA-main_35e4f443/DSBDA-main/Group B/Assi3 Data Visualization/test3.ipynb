# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Placement_Prediction_data.csv')
data
# Out:
#       Unnamed: 0  StudentId  CGPA  Major Projects  Workshops/Certificatios  \
# 0              0          1   7.5             1.0                        1
# 1              1          2   8.9             0.0                        3
# 2              2          3   7.3             1.0                        2
# 3              3          4   7.5             1.0                        1
# 4              4          5   8.3             1.0                        2
# ...          ...        ...   ...             ...                      ...
# 9995        9995       9996   7.5             1.0                        1
# 9996        9996       9997   7.4             0.0                        1
# 9997        9997       9998   8.4             1.0                        3
# 9998        9998       9999   8.9             0.0                        3
# 9999        9999      10000   8.4             0.0                        1
#
#       Mini Projects  Skills  Communication Skill Rating Internship Hackathon  \
# 0               1.0     6.0                         4.4         No        No
# 1               2.0     9.0                         4.0        Yes       Yes
# 2               2.0     8.0                         4.8        Yes        No
# 3               2.0     8.0                         4.4        Yes       Yes
# 4               2.0     8.0                         4.5        Yes       Yes
# ...             ...     ...                         ...        ...       ...
# 9995            2.0     7.0                         3.9        Yes        No
# 9996            0.0     9.0                         4.8         No        No
# 9997            0.0     7.0                         4.8        Yes       Yes
# 9998            2.0     8.0                         4.8        Yes       Yes
# 9999            1.0     6.0                         3.8         No        No
#
#       12th Percentage  10th Percentage  backlogs PlacementStatus
# 0                  61               79       2.0       NotPlaced
# 1                  78               82       0.0          Placed
# 2                  79               80       2.0       NotPlaced
# 3                  81               80       0.0          Placed
# 4                  74               88       0.0          Placed
# ...               ...              ...       ...             ...
# 9995               85               66       4.0       NotPlaced
# 9996               84               67       1.0          Placed
# 9997               79               81       0.0          Placed
# 9998               71               85       0.0          Placed
# 9999               62               66       1.0       NotPlaced
#
# [10000 rows x 14 columns]

# %%
data = data.drop('Unnamed: 0',axis=1)
data
# Out:
#       StudentId  CGPA  Major Projects  Workshops/Certificatios  Mini Projects  \
# 0             1   7.5             1.0                        1            1.0
# 1             2   8.9             0.0                        3            2.0
# 2             3   7.3             1.0                        2            2.0
# 3             4   7.5             1.0                        1            2.0
# 4             5   8.3             1.0                        2            2.0
# ...         ...   ...             ...                      ...            ...
# 9995       9996   7.5             1.0                        1            2.0
# 9996       9997   7.4             0.0                        1            0.0
# 9997       9998   8.4             1.0                        3            0.0
# 9998       9999   8.9             0.0                        3            2.0
# 9999      10000   8.4             0.0                        1            1.0
#
#       Skills  Communication Skill Rating Internship Hackathon  \
# 0        6.0                         4.4         No        No
# 1        9.0                         4.0        Yes       Yes
# 2        8.0                         4.8        Yes        No
# 3        8.0                         4.4        Yes       Yes
# 4        8.0                         4.5        Yes       Yes
# ...      ...                         ...        ...       ...
# 9995     7.0                         3.9        Yes        No
# 9996     9.0                         4.8         No        No
# 9997     7.0                         4.8        Yes       Yes
# 9998     8.0                         4.8        Yes       Yes
# 9999     6.0                         3.8         No        No
#
#       12th Percentage  10th Percentage  backlogs PlacementStatus
# 0                  61               79       2.0       NotPlaced
# 1                  78               82       0.0          Placed
# 2                  79               80       2.0       NotPlaced
# 3                  81               80       0.0          Placed
# 4                  74               88       0.0          Placed
# ...               ...              ...       ...             ...
# 9995               85               66       4.0       NotPlaced
# 9996               84               67       1.0          Placed
# 9997               79               81       0.0          Placed
# 9998               71               85       0.0          Placed
# 9999               62               66       1.0       NotPlaced
#
# [10000 rows x 13 columns]

# %%
data = data.drop('StudentId',axis=1)
data
# Out:
#       CGPA  Major Projects  Workshops/Certificatios  Mini Projects  Skills  \
# 0      7.5             1.0                        1            1.0     6.0
# 1      8.9             0.0                        3            2.0     9.0
# 2      7.3             1.0                        2            2.0     8.0
# 3      7.5             1.0                        1            2.0     8.0
# 4      8.3             1.0                        2            2.0     8.0
# ...    ...             ...                      ...            ...     ...
# 9995   7.5             1.0                        1            2.0     7.0
# 9996   7.4             0.0                        1            0.0     9.0
# 9997   8.4             1.0                        3            0.0     7.0
# 9998   8.9             0.0                        3            2.0     8.0
# 9999   8.4             0.0                        1            1.0     6.0
#
#       Communication Skill Rating Internship Hackathon  12th Percentage  \
# 0                            4.4         No        No               61
# 1                            4.0        Yes       Yes               78
# 2                            4.8        Yes        No               79
# 3                            4.4        Yes       Yes               81
# 4                            4.5        Yes       Yes               74
# ...                          ...        ...       ...              ...
# 9995                         3.9        Yes        No               85
# 9996                         4.8         No        No               84
# 9997                         4.8        Yes       Yes               79
# 9998                         4.8        Yes       Yes               71
# 9999                         3.8         No        No               62
#
#       10th Percentage  backlogs PlacementStatus
# 0                  79       2.0       NotPlaced
# 1                  82       0.0          Placed
# 2                  80       2.0       NotPlaced
# 3                  80       0.0          Placed
# 4                  88       0.0          Placed
# ...               ...       ...             ...
# 9995               66       4.0       NotPlaced
# 9996               67       1.0          Placed
# 9997               81       0.0          Placed
# 9998               85       0.0          Placed
# 9999               66       1.0       NotPlaced
#
# [10000 rows x 12 columns]

# %%
data.isnull().sum()
# Out:
# CGPA                          0
# Major Projects                1
# Workshops/Certificatios       0
# Mini Projects                 1
# Skills                        3
# Communication Skill Rating    0
# Internship                    0
# Hackathon                     0
# 12th Percentage               0
# 10th Percentage               0
# backlogs                      1
# PlacementStatus               0
# dtype: int64

# %%
number = data.select_dtypes(include='number')
mv = number.mean()
data = data.fillna(mv)
data
# Out:
#       CGPA  Major Projects  Workshops/Certificatios  Mini Projects  Skills  \
# 0      7.5             1.0                        1            1.0     6.0
# 1      8.9             0.0                        3            2.0     9.0
# 2      7.3             1.0                        2            2.0     8.0
# 3      7.5             1.0                        1            2.0     8.0
# 4      8.3             1.0                        2            2.0     8.0
# ...    ...             ...                      ...            ...     ...
# 9995   7.5             1.0                        1            2.0     7.0
# 9996   7.4             0.0                        1            0.0     9.0
# 9997   8.4             1.0                        3            0.0     7.0
# 9998   8.9             0.0                        3            2.0     8.0
# 9999   8.4             0.0                        1            1.0     6.0
#
#       Communication Skill Rating Internship Hackathon  12th Percentage  \
# 0                            4.4         No        No               61
# 1                            4.0        Yes       Yes               78
# 2                            4.8        Yes        No               79
# 3                            4.4        Yes       Yes               81
# 4                            4.5        Yes       Yes               74
# ...                          ...        ...       ...              ...
# 9995                         3.9        Yes        No               85
# 9996                         4.8         No        No               84
# 9997                         4.8        Yes       Yes               79
# 9998                         4.8        Yes       Yes               71
# 9999                         3.8         No        No               62
#
#       10th Percentage  backlogs PlacementStatus
# 0                  79       2.0       NotPlaced
# 1                  82       0.0          Placed
# 2                  80       2.0       NotPlaced
# 3                  80       0.0          Placed
# 4                  88       0.0          Placed
# ...               ...       ...             ...
# 9995               66       4.0       NotPlaced
# 9996               67       1.0          Placed
# 9997               81       0.0          Placed
# 9998               85       0.0          Placed
# 9999               66       1.0       NotPlaced
#
# [10000 rows x 12 columns]

# %%
data.isnull().sum()
# Out:
# CGPA                          0
# Major Projects                0
# Workshops/Certificatios       0
# Mini Projects                 0
# Skills                        0
# Communication Skill Rating    0
# Internship                    0
# Hackathon                     0
# 12th Percentage               0
# 10th Percentage               0
# backlogs                      0
# PlacementStatus               0
# dtype: int64

# %%
sns.set_style("whitegrid")

# %%
data.columns
# Out:
# Index(['CGPA', 'Major Projects', 'Workshops/Certificatios', 'Mini Projects',
#        'Skills', 'Communication Skill Rating', 'Internship', 'Hackathon',
#        '12th Percentage', '10th Percentage', 'backlogs', 'PlacementStatus'],
#       dtype='object')

# %%
sns.countplot(x="Internship",hue="PlacementStatus", data=data)
plt.show()

# %%
sns.barplot(x="PlacementStatus", y="CGPA", data=data)
plt.show()

# %%
sns.scatterplot(x="CGPA", y="Skills",hue="PlacementStatus", data=data)
plt.show()

# %%
sns.heatmap(data.corr(numeric_only=True),annot = True, cmap = "coolwarm")
plt.show()

# %%
sns.histplot(data["Communication Skill Rating"], bins = 20,kde=True)
plt.show()

# %%
sns.boxplot(x="PlacementStatus", y="CGPA", data=data)
plt.show()

# %%
sns.pairplot(data,vars=["CGPA", "12th Percentage", "Skills"],hue="PlacementStatus", palette="husl")

# %%
data["PlacementStatus"].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
sns.violinplot(x="PlacementStatus", y="CGPA", data=data)
plt.show()
